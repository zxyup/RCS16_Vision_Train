# %%
# !pip install matplotlib -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: matplotlib in d:\minicondafile\envs\pytorch\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\minicondafile\envs\pytorch\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in d:\minicondafile\envs\pytorch\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\minicondafile\envs\pytorch\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\minicondafile\envs\pytorch\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in d:\minicondafile\envs\pytorch\lib\site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in d:\minicondafile\envs\pytorch\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\minicondafile\envs\pytorch\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\minicondafile\envs\pytorch\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\minicondafile\envs\pytorch\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\minicondafile\envs\pytorch\lib\site-packages (from matplotlib) (6.0.1)
# Requirement already satisfied: zipp>=3.1.0 in d:\minicondafile\envs\pytorch\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.2)
# Requirement already satisfied: six>=1.5 in d:\minicondafile\envs\pytorch\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 数据准备
np.random.seed(7)
x=5 *np.random.rand(100,1)
x-=2
y=5*x**3+-6*x**2+3*x+np.random.randn(100,1)*0.8
plt.scatter(x,y,marker='+',color='blue')

# %%
# 数据处理
import torch
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
x=torch.from_numpy(x).float()
y=torch.from_numpy(y).float()
dataset=TensorDataset(x,y)
dataloader=DataLoader(dataset,batch_size=16,shuffle=True)

# %%
print('Len of DataLoader',len(dataloader))
for index,(data,label) in enumerate(dataloader):
    print(f'index={index},num={len(data):2}')#,data={data},label={label}
# Out:
# Len of DataLoader 7
# index=0,num=16
# index=1,num=16
# index=2,num=16
# index=3,num=16
# index=4,num=16
# index=5,num=16
# index=6,num= 4

# %%
epoch=800
lr=0.00074
a3=torch.randn(1,requires_grad=True)
a2=torch.randn(1,requires_grad=True)
a1=torch.randn(1,requires_grad=True)
a0=torch.randn(1,requires_grad=True)
print(a3)
print(a2)
print(a1)
Loss=[]
for epoch in range(1,epoch+1):
    sum_loss=0
    for batch_id,(bx,by) in enumerate(dataloader):
        h =a3*(bx**3) + a2*(bx**2) + a1*bx +a0
        loss= torch.mean((h-by)**2)
        #print('Loss',loss)
        sum_loss+=loss.item()
        loss.backward()
        a3.data-=lr*a3.grad.data
        a2.data-=lr*a2.grad.data
        a1.data-=lr*a1.grad.data
        a0.data-=lr*a0.grad.data

        a3.grad.zero_()
        a2.grad.zero_()
        a1.grad.zero_()
        a0.grad.zero_()

    Loss.append(sum_loss)
# print(loss.item())
# print(f'w:{w.item()}')
# print(f'b:{b.item()}')
Loss_x=[i for i in range(1,epoch+1)]
fig = plt.figure(figsize=(11,4))
plt.subplot(1,2,2)
plt.plot(Loss_x,Loss)
plt.title("Xiaomin Wang")
a3=a3.item()
a2=a2.item()
a1=a1.item()
a0=a0.item()
xx=np.linspace(-2,3,100)
h=a3*(xx**3) + a2*(xx**2) + a1*xx +a0
plt.subplot(1,2,1)
plt.scatter(x,y,marker='+',color='red')
plt.title("Xiaomin Wang")
plt.plot(xx,h)

plt.show()
# Out:
# tensor([0.3994], requires_grad=True)
# tensor([1.1354], requires_grad=True)
# tensor([0.7650], requires_grad=True)
